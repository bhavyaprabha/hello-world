# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_excel('Phase1_dataset.xlsx',sheet_name='Leather Safety Gloves')
df2=pd.read_excel('Phase1_dataset.xlsx',sheet_name='Ladies Kurta')
df3=pd.read_excel('Phase1_dataset.xlsx',sheet_name='Impact Drill')

# %%
df1.head()
# Out:
#            Category Name  Unit  Price
# 0  Leather Safety Gloves  Pair     10
# 1  Leather Safety Gloves  Pair     12
# 2  Leather Safety Gloves  Pair     12
# 3  Leather Safety Gloves  Pair     20
# 4  Leather Safety Gloves  Pair     23

# %%
df1.shape
# Out:
# (144, 3)

# %%
df1['Category Name'].unique()
# Out:
# array(['Leather Safety Gloves'], dtype=object)

# %%
df1['Unit'].unique()
# Out:
# array(['Pair', 'Piece', 'pack', 'Unit', 'Pack', 'Unit/Onwards', 'Pair(s)',
#        'unit', 'Set', 'Pieces'], dtype=object)

# %%
df1
# Out:
#              Category Name     Unit  Price
# 0    Leather Safety Gloves     Pair     10
# 1    Leather Safety Gloves     Pair     12
# 2    Leather Safety Gloves     Pair     12
# 3    Leather Safety Gloves     Pair     20
# 4    Leather Safety Gloves     Pair     23
# 5    Leather Safety Gloves     Pair     25
# 6    Leather Safety Gloves     Pair     25
# 7    Leather Safety Gloves     Pair     25
# 8    Leather Safety Gloves     Pair     29
# 9    Leather Safety Gloves     Pair     30
# 10   Leather Safety Gloves     Pair     31
# 11   Leather Safety Gloves     Pair     32
# 12   Leather Safety Gloves     Pair     35
# 13   Leather Safety Gloves     Pair     35
# 14   Leather Safety Gloves     Pair     38
# 15   Leather Safety Gloves     Pair     38
# 16   Leather Safety Gloves     Pair     38
# 17   Leather Safety Gloves    Piece     40
# 18   Leather Safety Gloves     Pair     40
# 19   Leather Safety Gloves     Pair     40
# 20   Leather Safety Gloves     Pair     40
# 21   Leather Safety Gloves    Piece     40
# 22   Leather Safety Gloves     Pair     40
# 23   Leather Safety Gloves    Piece     40
# 24   Leather Safety Gloves     Pair     40
# 25   Leather Safety Gloves     Pair     45
# 26   Leather Safety Gloves     Pair     45
# 27   Leather Safety Gloves     Pair     45
# 28   Leather Safety Gloves     Pair     45
# 29   Leather Safety Gloves     Pair     45
# ..                     ...      ...    ...
# 114  Leather Safety Gloves     Pair    200
# 115  Leather Safety Gloves     Pair    200
# 116  Leather Safety Gloves     Pair    200
# 117  Leather Safety Gloves     Pair    230
# 118  Leather Safety Gloves     Pair    240
# 119  Leather Safety Gloves    Piece    250
# 120  Leather Safety Gloves     Pair    250
# 121  Leather Safety Gloves     Pair    250
# 122  Leather Safety Gloves     Pair    250
# 123  Leather Safety Gloves     Pair    250
# 124  Leather Safety Gloves    Piece    300
# 125  Leather Safety Gloves     Pair    350
# 126  Leather Safety Gloves     unit    366
# 127  Leather Safety Gloves  Pair(s)    450
# 128  Leather Safety Gloves      Set    600
# 129  Leather Safety Gloves   Pieces    695
# 130  Leather Safety Gloves     Pack    781
# 131  Leather Safety Gloves     unit    785
# 132  Leather Safety Gloves     Unit    786
# 133  Leather Safety Gloves     unit    974
# 134  Leather Safety Gloves     unit    974
# 135  Leather Safety Gloves     pack   1150
# 136  Leather Safety Gloves     unit   1152
# 137  Leather Safety Gloves     Pack   1440
# 138  Leather Safety Gloves     unit   1575
# 139  Leather Safety Gloves     pack   2210
# 140  Leather Safety Gloves     unit   2594
# 141  Leather Safety Gloves     unit   4587
# 142  Leather Safety Gloves     unit   8978
# 143  Leather Safety Gloves     pack  18974
#
# [144 rows x 3 columns]

# %%
df1['Price'].unique()
# Out:
# array([   10,    12,    20,    23,    25,    29,    30,    31,    32,
#           35,    38,    40,    45,    50,    51,    52,    55,    60,
#           65,    67,    68,    70,    75,    78,    80,    85,    90,
#           95,    96,   100,   110,   120,   125,   130,   135,   145,
#          150,   155,   170,   175,   177,   180,   190,   195,   199,
#          200,   230,   240,   250,   300,   350,   366,   450,   600,
#          695,   781,   785,   786,   974,  1150,  1152,  1440,  1575,
#         2210,  2594,  4587,  8978, 18974], dtype=int64)

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Unit',data=df1)

# %%
df1.groupby('Unit')['Price'].unique()
# Out:
# Unit
# Pack                                              [78, 781, 1440]
# Pair            [10, 12, 20, 23, 25, 29, 30, 31, 32, 35, 38, 4...
# Pair(s)                                                [180, 450]
# Piece                                         [40, 150, 250, 300]
# Pieces                                                      [695]
# Set                                                         [600]
# Unit                                               [70, 100, 786]
# Unit/Onwards                                                [100]
# pack                                 [51, 150, 1150, 2210, 18974]
# unit                [366, 785, 974, 1152, 1575, 2594, 4587, 8978]
# Name: Price, dtype: object

# %%
df1[df1['Unit']=='Pair'].max()
# Out:
# Category Name    Leather Safety Gloves
# Unit                              Pair
# Price                              350
# dtype: object

# %%
df3.describe()
# Out:
#               Price
# count    247.000000
# mean    6570.153846
# std     9543.845737
# min        2.000000
# 25%     2107.500000
# 50%     3098.000000
# 75%     6020.000000
# max    55000.000000
